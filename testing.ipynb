# %% [markdown]
# # How to Train Detectron2 for Custom Instance Segmentation
#
# This tutorial is based on the [Detectron2 repository](https://github.com/facebookresearch/detectron2) by Facebook. This notebook shows training on **your own custom instance segmentation objects**.
#
# ### Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the blog post on [how to train Detectron2 for custom instance segmentation](https://blog.roboflow.ai/custom-detectron2-instance-segmentation/), concurrently.
#
# ### Steps Covered in this Tutorial
#
# In this tutorial, we will walk through the steps required to train Detectron2 on your custom instance segmentation objects. We use a public [American Sign Language instance segmentation dataset](https://public.roboflow.ai/object-detection/bccd), which is open source and free to use. You can also use this notebook on your own data.
#
# To train our segmenter we take the following steps:
#
# * Install Detectron2 dependencies
# * Download custom instance segmentation data from Roboflow
# * Visualize Detectron2 training data
# * Write our Detectron2 Training configuration
# * Run Detectron2 training
# * Evaluate Dectron2 performance
# * Run Detectron2 inference on test images
# * Export saved Detectron2 weights for future inference
#
# ### **About**
#
# [Roboflow](https://roboflow.com) enables teams to deploy custom computer vision models quickly and accurately. Convert data from to annotation format, assess dataset health, preprocess, augment, and more. It's free for your first 1000 source images.
#
# **Looking for a vision model available via API without hassle? Try Roboflow Train.**
#
# ![Roboflow Wordmark](https://i.imgur.com/dcLNMhV.png)

# %% [markdown]
# # Install Roboflow and Detectron2 Pip Packages, Import Deps

# %%
# !python -m pip install roboflow
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'

# %%
import logging
import torch
from collections import OrderedDict
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import os, json, cv2, random

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog
from detectron2.data.datasets import register_coco_instances
from detectron2.engine import DefaultTrainer
from detectron2.utils.visualizer import ColorMode
from detectron2.solver import build_lr_scheduler, build_optimizer
from detectron2.checkpoint import DetectionCheckpointer, PeriodicCheckpointer
from detectron2.utils.events import EventStorage
from detectron2.modeling import build_model
import detectron2.utils.comm as comm
from detectron2.engine import default_argument_parser, default_setup, default_writers, launch
from detectron2.data import (
    MetadataCatalog,
    build_detection_test_loader,
    build_detection_train_loader,
)
from detectron2.evaluation import (
    CityscapesInstanceEvaluator,
    CityscapesSemSegEvaluator,
    COCOEvaluator,
    COCOPanopticEvaluator,
    DatasetEvaluators,
    LVISEvaluator,
    PascalVOCDetectionEvaluator,
    SemSegEvaluator,
    inference_on_dataset,
    print_csv_format,
)

from roboflow import Roboflow

from matplotlib import pyplot as plt
from PIL import Image

# %% [markdown]
# # Download dataset via Roboflow pip package and show a sample annotation

# %%
# VERSION = 2
# rf = Roboflow(api_key="VFsc1LXKlbV2exD1houn")
# project = rf.workspace("team-roboflow").project("american-sign-language-poly")
# dataset = project.version(VERSION).download("coco")
# Out:
# [Errno 2] No such file or directory: 'Mydrive'
# /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
register_coco_instances("co_train", {}, f"/content/drive/MyDrive/CocaCola Images/train/labels_my-project-name_2024-04-16-04-43-13.json", f"/content/drive/MyDrive/CocaCola Images/train/")
register_coco_instances("ca_test", {}, f"/content/drive/MyDrive/CocaCola Images/test/labels_my-project-name_2024-04-16-02-40-51.json", f"/content/drive/MyDrive/CocaCola Images/test/")
register_coco_instances("ca_val", {}, f"/content/drive/MyDrive/CocaCola Images (1)/val/labels_my-project-name_2024-04-16-04-31-19.json", f"/content/drive/MyDrive/CocaCola Images (1)/val/")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-905148c5bcfa> in <cell line: 18>()
#      16 # Create a custom dataset mapper
#      17 from detectron2.data import DatasetMapper
# ---> 18 mapper = DatasetMapper(
#      19     cfg,
#      20     is_train=True,
#
# /usr/local/lib/python3.10/dist-packages/detectron2/config/config.py in wrapped(self, *args, **kwargs)
#     188             if _called_with_cfg(*args, **kwargs):
#     189                 explicit_args = _get_args_from_config(from_config_func, *args, **kwargs)
# --> 190                 init_func(self, **explicit_args)
#     191             else:
#     192                 init_func(self, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/detectron2/data/dataset_mapper.py in __init__(self, is_train, augmentations, image_format, use_instance_mask, use_keypoint, instance_mask_format, keypoint_hflip_indices, precomputed_proposal_topk, recompute_boxes)
#      70         # fmt: off
#      71         self.is_train               = is_train
# ---> 72         self.augmentations          = T.AugmentationList(augmentations)
#      73         self.image_format           = image_format
#      74         self.use_instance_mask      = use_instance_mask
#
# /usr/local/lib/python3.10/dist-packages/detectron2/data/transforms/augmentation.py in __init__(self, augs)
#     260         """
#     261         super().__init__()
# --> 262         self.augs = [_transform_to_aug(x) for x in augs]
#     263
#     264     def __call__(self, aug_input) -> TransformList:
#
# TypeError: 'AugmentationList' object is not iterable

# %%
dataset_train = DatasetCatalog.get("ca_val")
fig, ax = plt.subplots()
dataset_dict = random.choice(dataset_train)
im = Image.open(dataset_dict['file_name'])
ax.imshow(im)
for ann in dataset_dict['annotations']:
    for poly in ann['segmentation']:
        x = poly[0::2]
        y = poly[1::2]
        ax.plot(x,y, linewidth=2, color='red')
# Out:
# [04/16 14:36:30 d2.data.datasets.coco]: Loaded 7 images in COCO format from /content/drive/MyDrive/CocaCola Images (1)/val/labels_my-project-name_2024-04-16-04-31-19.json

# %% [markdown]
# # Configure Detectron2 for fine tuning from COCO, Define training loop helper functions (from detectron2 repo), Run custom training loop

# %%
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("co_train",)#Train dataset registered in a previous cell
cfg.DATASETS.TEST = ("ca_test",)#Test dataset registered in a previous cell
cfg.DATALOADER.NUM_WORKERS = 2
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")  # Let training initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 2
cfg.SOLVER.BASE_LR = 0.00025
cfg.SOLVER.MAX_ITER = 1000 #We found that with a patience of 500, training will early stop before 10,000 iterations
cfg.SOLVER.STEPS = []
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 512
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 2 # 26 letters plus one super class
cfg.TEST.EVAL_PERIOD = 0 # Increase this number if you want to monitor validation performance during training

PATIENCE = 300 #Early stopping will occur after N iterations of no imporovement in total_loss

os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)

# %%
def get_evaluator(cfg, dataset_name, output_folder=None):
    """
    Create evaluator(s) for a given dataset.
    This uses the special metadata "evaluator_type" associated with each builtin dataset.
    For your own dataset, you can simply create an evaluator manually in your
    script and do not have to worry about the hacky if-else logic here.
    """
    if output_folder is None:
        output_folder = os.path.join(cfg.OUTPUT_DIR, "inference")
    evaluator_list = []
    evaluator_type = MetadataCatalog.get(dataset_name).evaluator_type
    if evaluator_type in ["sem_seg", "coco_panoptic_seg"]:
        evaluator_list.append(
            SemSegEvaluator(
                dataset_name,
                distributed=True,
                output_dir=output_folder,
            )
        )
    if evaluator_type in ["coco", "coco_panoptic_seg"]:
        evaluator_list.append(COCOEvaluator(dataset_name, output_dir=output_folder))
    if evaluator_type == "coco_panoptic_seg":
        evaluator_list.append(COCOPanopticEvaluator(dataset_name, output_folder))
    if evaluator_type == "cityscapes_instance":
        return CityscapesInstanceEvaluator(dataset_name)
    if evaluator_type == "cityscapes_sem_seg":
        return CityscapesSemSegEvaluator(dataset_name)
    if evaluator_type == "pascal_voc":
        return PascalVOCDetectionEvaluator(dataset_name)
    if evaluator_type == "lvis":
        return LVISEvaluator(dataset_name, cfg, True, output_folder)
    if len(evaluator_list) == 0:
        raise NotImplementedError(
            "no Evaluator for the dataset {} with the type {}".format(dataset_name, evaluator_type)
        )
    if len(evaluator_list) == 1:
        return evaluator_list[0]
    return DatasetEvaluators(evaluator_list)

def do_test(cfg, model):
    results = OrderedDict()
    for dataset_name in cfg.DATASETS.TEST:
        data_loader = build_detection_test_loader(cfg, dataset_name)
        evaluator = get_evaluator(
            cfg, dataset_name, os.path.join(cfg.OUTPUT_DIR, "inference", dataset_name)
        )
        results_i = inference_on_dataset(model, data_loader, evaluator)
        results[dataset_name] = results_i
        if comm.is_main_process():
            logger.info("Evaluation results for {} in csv format:".format(dataset_name))
            print_csv_format(results_i)
    if len(results) == 1:
        results = list(results.values())[0]
    return results


logger = logging.getLogger("detectron2")
resume=False
model = build_model(cfg)
optimizer = build_optimizer(cfg, model)
scheduler = build_lr_scheduler(cfg, optimizer)

BEST_LOSS = np.inf

checkpointer = DetectionCheckpointer(
    model, cfg.OUTPUT_DIR, optimizer=optimizer, scheduler=scheduler
)
start_iter = (
    checkpointer.resume_or_load(cfg.MODEL.WEIGHTS, resume=resume).get("iteration", -1) + 1
)
prev_iter = start_iter
max_iter = cfg.SOLVER.MAX_ITER

periodic_checkpointer = PeriodicCheckpointer(
    checkpointer, cfg.SOLVER.CHECKPOINT_PERIOD, max_iter=max_iter
)

writers = default_writers(cfg.OUTPUT_DIR, max_iter) if comm.is_main_process() else []

# compared to "train_net.py", we do not support accurate timing and
# precise BN here, because they are not trivial to implement in a small training loop
data_loader = build_detection_train_loader(cfg)
logger.info("Starting training from iteration {}".format(start_iter))
patience_counter = 0
with EventStorage(start_iter) as storage:
    for data, iteration in zip(data_loader, range(start_iter, max_iter)):
        storage.iter = iteration

        loss_dict = model(data)
        losses = sum(loss_dict.values())
        assert torch.isfinite(losses).all(), loss_dict

        loss_dict_reduced = {k: v.item() for k, v in comm.reduce_dict(loss_dict).items()}
        losses_reduced = sum(loss for loss in loss_dict_reduced.values())
        if comm.is_main_process():
            storage.put_scalars(total_loss=losses_reduced, **loss_dict_reduced)

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()
        storage.put_scalar("lr", optimizer.param_groups[0]["lr"], smoothing_hint=False)
        scheduler.step()

        if (
            cfg.TEST.EVAL_PERIOD > 0
            and (iteration + 1) % cfg.TEST.EVAL_PERIOD == 0
            and iteration != max_iter - 1
        ):
            do_test(cfg, model)
            # Compared to "train_net.py", the test results are not dumped to EventStorage
            comm.synchronize()

        if iteration - start_iter > 5 and (
            (iteration + 1) % 20 == 0 or iteration == max_iter - 1
        ):
            for writer in writers:
                writer.write()
        periodic_checkpointer.step(iteration)

        if iteration > prev_iter:
            prev_iter = iteration
            if losses_reduced < BEST_LOSS:
                BEST_LOSS = losses_reduced
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter % 100 == 0:
                    print(f"Loss has not improved for {patience_counter} iterations")
                if patience_counter >= PATIENCE:
                    print(f"EARLY STOPPING")
                    break

do_test(cfg, model)
# Out:
# [04/16 15:49:37 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl ...
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (3, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (3,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (8, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (8,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (2, 256, 1, 1) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (2,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}
# [04/16 15:49:37 d2.data.datasets.coco]: Loaded 193 images in COCO format from /content/drive/MyDrive/CocaCola Images/train/labels_my-project-name_2024-04-16-04-43-13.json
# [04/16 15:49:37 d2.data.build]: Removed 0 images with no usable annotations. 193 images left.
# [04/16 15:49:37 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [04/16 15:49:37 d2.data.build]: Using training sampler TrainingSampler
# [04/16 15:49:37 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [04/16 15:49:37 d2.data.common]: Serializing 193 elements to byte tensors and concatenating them all ...
# [04/16 15:49:37 d2.data.common]: Serialized dataset takes 0.13 MiB
# [04/16 15:49:37 d2.data.build]: Making batched data loader with batch_size=2
# [04/16 15:49:37 detectron2]: Starting training from iteration 0
# os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
# [04/16 15:49:46 d2.utils.events]:  iter: 19  total_loss: 1.833  loss_cls: 0.9742  loss_box_reg: 0.1549  loss_mask: 0.697  loss_rpn_cls: 0.001501  loss_rpn_loc: 0.00577     lr: 4.9953e-06  max_mem: 2673M
# [04/16 15:49:55 d2.utils.events]:  eta: 0:07:09  iter: 39  total_loss: 1.706  loss_cls: 0.875  loss_box_reg: 0.1755  loss_mask: 0.661  loss_rpn_cls: 0.002501  loss_rpn_loc: 0.006102     lr: 9.9902e-06  max_mem: 2761M
# [04/16 15:50:04 d2.utils.events]:  eta: 0:07:02  iter: 59  total_loss: 1.393  loss_cls: 0.6493  loss_box_reg: 0.1238  loss_mask: 0.6164  loss_rpn_cls: 0.002343  loss_rpn_loc: 0.006528     lr: 1.4985e-05  max_mem: 2761M
# [04/16 15:50:13 d2.utils.events]:  eta: 0:07:00  iter: 79  total_loss: 1.154  loss_cls: 0.4424  loss_box_reg: 0.157  loss_mask: 0.5442  loss_rpn_cls: 0.002235  loss_rpn_loc: 0.006142     lr: 1.998e-05  max_mem: 2817M
# [04/16 15:50:22 d2.utils.events]:  eta: 0:07:02  iter: 99  total_loss: 1.08  loss_cls: 0.333  loss_box_reg: 0.2067  loss_mask: 0.4897  loss_rpn_cls: 0.003465  loss_rpn_loc: 0.01028     lr: 2.4975e-05  max_mem: 2817M
# [04/16 15:50:31 d2.utils.events]:  eta: 0:06:29  iter: 119  total_loss: 0.792  loss_cls: 0.2183  loss_box_reg: 0.1342  loss_mask: 0.4209  loss_rpn_cls: 0.002622  loss_rpn_loc: 0.008333     lr: 2.997e-05  max_mem: 2851M
# [04/16 15:50:40 d2.utils.events]:  eta: 0:06:24  iter: 139  total_loss: 0.7  loss_cls: 0.1817  loss_box_reg: 0.1795  loss_mask: 0.3229  loss_rpn_cls: 0.001662  loss_rpn_loc: 0.008349     lr: 3.4965e-05  max_mem: 2851M
# [04/16 15:50:49 d2.utils.events]:  eta: 0:06:32  iter: 159  total_loss: 0.7278  loss_cls: 0.1837  loss_box_reg: 0.2165  loss_mask: 0.3528  loss_rpn_cls: 0.001642  loss_rpn_loc: 0.007324     lr: 3.996e-05  max_mem: 2851M
# [04/16 15:50:59 d2.utils.events]:  eta: 0:06:46  iter: 179  total_loss: 0.6413  loss_cls: 0.1445  loss_box_reg: 0.1377  loss_mask: 0.3286  loss_rpn_cls: 0.003017  loss_rpn_loc: 0.0066     lr: 4.4955e-05  max_mem: 2852M
# [04/16 15:51:09 d2.utils.events]:  eta: 0:06:22  iter: 199  total_loss: 0.5741  loss_cls: 0.123  loss_box_reg: 0.1457  loss_mask: 0.2805  loss_rpn_cls: 0.00169  loss_rpn_loc: 0.004865     lr: 4.995e-05  max_mem: 2852M
# [04/16 15:51:18 d2.utils.events]:  eta: 0:06:05  iter: 219  total_loss: 0.5787  loss_cls: 0.1344  loss_box_reg: 0.1777  loss_mask: 0.2787  loss_rpn_cls: 0.002412  loss_rpn_loc: 0.007204     lr: 5.4945e-05  max_mem: 2852M
# [04/16 15:51:28 d2.utils.events]:  eta: 0:05:53  iter: 239  total_loss: 0.4588  loss_cls: 0.1041  loss_box_reg: 0.1652  loss_mask: 0.1996  loss_rpn_cls: 0.0008611  loss_rpn_loc: 0.007355     lr: 5.994e-05  max_mem: 2852M
# [04/16 15:51:37 d2.utils.events]:  eta: 0:05:37  iter: 259  total_loss: 0.4665  loss_cls: 0.1111  loss_box_reg: 0.1781  loss_mask: 0.1753  loss_rpn_cls: 0.001003  loss_rpn_loc: 0.004823     lr: 6.4935e-05  max_mem: 2852M
# [04/16 15:51:46 d2.utils.events]:  eta: 0:05:42  iter: 279  total_loss: 0.458  loss_cls: 0.1031  loss_box_reg: 0.1672  loss_mask: 0.1593  loss_rpn_cls: 0.00102  loss_rpn_loc: 0.006666     lr: 6.993e-05  max_mem: 2852M
# [04/16 15:51:55 d2.utils.events]:  eta: 0:05:19  iter: 299  total_loss: 0.4106  loss_cls: 0.09625  loss_box_reg: 0.1631  loss_mask: 0.1384  loss_rpn_cls: 0.001943  loss_rpn_loc: 0.004313     lr: 7.4925e-05  max_mem: 2852M
# [04/16 15:52:05 d2.utils.events]:  eta: 0:05:13  iter: 319  total_loss: 0.4219  loss_cls: 0.09555  loss_box_reg: 0.1578  loss_mask: 0.1568  loss_rpn_cls: 0.001975  loss_rpn_loc: 0.005451     lr: 7.992e-05  max_mem: 2852M
# [04/16 15:52:14 d2.utils.events]:  eta: 0:04:58  iter: 339  total_loss: 0.4134  loss_cls: 0.08765  loss_box_reg: 0.1611  loss_mask: 0.1421  loss_rpn_cls: 0.000366  loss_rpn_loc: 0.006184     lr: 8.4915e-05  max_mem: 2852M
# [04/16 15:52:23 d2.utils.events]:  eta: 0:05:11  iter: 359  total_loss: 0.4039  loss_cls: 0.07747  loss_box_reg: 0.1468  loss_mask: 0.1482  loss_rpn_cls: 0.0007057  loss_rpn_loc: 0.009058     lr: 8.991e-05  max_mem: 2852M
# [04/16 15:52:32 d2.utils.events]:  eta: 0:04:44  iter: 379  total_loss: 0.4009  loss_cls: 0.1023  loss_box_reg: 0.1682  loss_mask: 0.1389  loss_rpn_cls: 0.0002302  loss_rpn_loc: 0.008737     lr: 9.4905e-05  max_mem: 2852M
# [04/16 15:52:42 d2.utils.events]:  eta: 0:04:45  iter: 399  total_loss: 0.3641  loss_cls: 0.08364  loss_box_reg: 0.1511  loss_mask: 0.1333  loss_rpn_cls: 0.0003143  loss_rpn_loc: 0.005217     lr: 9.99e-05  max_mem: 2852M
# [04/16 15:52:52 d2.utils.events]:  eta: 0:04:36  iter: 419  total_loss: 0.4213  loss_cls: 0.0924  loss_box_reg: 0.1803  loss_mask: 0.1296  loss_rpn_cls: 0.001395  loss_rpn_loc: 0.009277     lr: 0.0001049  max_mem: 2852M
# [04/16 15:53:01 d2.utils.events]:  eta: 0:04:26  iter: 439  total_loss: 0.4051  loss_cls: 0.08818  loss_box_reg: 0.1719  loss_mask: 0.1271  loss_rpn_cls: 0.0006473  loss_rpn_loc: 0.005751     lr: 0.00010989  max_mem: 2852M
# [04/16 15:53:10 d2.utils.events]:  eta: 0:04:12  iter: 459  total_loss: 0.3062  loss_cls: 0.05884  loss_box_reg: 0.1367  loss_mask: 0.08672  loss_rpn_cls: 0.0004674  loss_rpn_loc: 0.009068     lr: 0.00011489  max_mem: 2852M
# [04/16 15:53:20 d2.utils.events]:  eta: 0:03:57  iter: 479  total_loss: 0.2875  loss_cls: 0.06957  loss_box_reg: 0.1191  loss_mask: 0.09419  loss_rpn_cls: 0.001506  loss_rpn_loc: 0.006661     lr: 0.00011988  max_mem: 2852M
# [04/16 15:53:29 d2.utils.events]:  eta: 0:04:07  iter: 499  total_loss: 0.2906  loss_cls: 0.06405  loss_box_reg: 0.1017  loss_mask: 0.09503  loss_rpn_cls: 0.0005025  loss_rpn_loc: 0.008163     lr: 0.00012488  max_mem: 2852M
# [04/16 15:53:39 d2.utils.events]:  eta: 0:03:50  iter: 519  total_loss: 0.2909  loss_cls: 0.06218  loss_box_reg: 0.1017  loss_mask: 0.1033  loss_rpn_cls: 0.001204  loss_rpn_loc: 0.006814     lr: 0.00012987  max_mem: 2852M
# [04/16 15:53:49 d2.utils.events]:  eta: 0:03:43  iter: 539  total_loss: 0.2206  loss_cls: 0.04479  loss_box_reg: 0.06994  loss_mask: 0.08868  loss_rpn_cls: 0.0008535  loss_rpn_loc: 0.00598     lr: 0.00013487  max_mem: 2852M
# [04/16 15:53:58 d2.utils.events]:  eta: 0:03:20  iter: 559  total_loss: 0.2877  loss_cls: 0.05732  loss_box_reg: 0.08044  loss_mask: 0.1111  loss_rpn_cls: 0.0001635  loss_rpn_loc: 0.008841     lr: 0.00013986  max_mem: 2852M
# [04/16 15:54:08 d2.utils.events]:  eta: 0:03:29  iter: 579  total_loss: 0.2574  loss_cls: 0.06162  loss_box_reg: 0.08078  loss_mask: 0.09231  loss_rpn_cls: 0.0004255  loss_rpn_loc: 0.007064     lr: 0.00014486  max_mem: 2858M
# [04/16 15:54:18 d2.utils.events]:  eta: 0:03:16  iter: 599  total_loss: 0.2233  loss_cls: 0.05977  loss_box_reg: 0.0583  loss_mask: 0.08925  loss_rpn_cls: 0.0003218  loss_rpn_loc: 0.006357     lr: 0.00014985  max_mem: 2858M
# [04/16 15:54:27 d2.utils.events]:  eta: 0:02:58  iter: 619  total_loss: 0.2174  loss_cls: 0.05877  loss_box_reg: 0.05881  loss_mask: 0.08208  loss_rpn_cls: 8.253e-05  loss_rpn_loc: 0.004739     lr: 0.00015485  max_mem: 2858M
# [04/16 15:54:37 d2.utils.events]:  eta: 0:02:51  iter: 639  total_loss: 0.2544  loss_cls: 0.0543  loss_box_reg: 0.07534  loss_mask: 0.09453  loss_rpn_cls: 0.0002105  loss_rpn_loc: 0.00453     lr: 0.00015984  max_mem: 2858M
# Loss has not improved for 100 iterations
# [04/16 15:54:46 d2.utils.events]:  eta: 0:02:45  iter: 659  total_loss: 0.2322  loss_cls: 0.05675  loss_box_reg: 0.07111  loss_mask: 0.09533  loss_rpn_cls: 0.0004733  loss_rpn_loc: 0.006298     lr: 0.00016484  max_mem: 2858M
# [04/16 15:54:56 d2.utils.events]:  eta: 0:02:40  iter: 679  total_loss: 0.2716  loss_cls: 0.06951  loss_box_reg: 0.07734  loss_mask: 0.1018  loss_rpn_cls: 0.0009049  loss_rpn_loc: 0.008124     lr: 0.00016983  max_mem: 2858M
# [04/16 15:55:05 d2.utils.events]:  eta: 0:02:15  iter: 699  total_loss: 0.193  loss_cls: 0.04608  loss_box_reg: 0.0551  loss_mask: 0.07671  loss_rpn_cls: 0.0003135  loss_rpn_loc: 0.005192     lr: 0.00017483  max_mem: 2858M
# [04/16 15:55:15 d2.utils.events]:  eta: 0:02:13  iter: 719  total_loss: 0.1914  loss_cls: 0.04206  loss_box_reg: 0.05226  loss_mask: 0.08004  loss_rpn_cls: 4.163e-05  loss_rpn_loc: 0.006492     lr: 0.00017982  max_mem: 2858M
# [04/16 15:55:24 d2.utils.events]:  eta: 0:02:02  iter: 739  total_loss: 0.2051  loss_cls: 0.05766  loss_box_reg: 0.05239  loss_mask: 0.08551  loss_rpn_cls: 0.0001934  loss_rpn_loc: 0.005297     lr: 0.00018482  max_mem: 2858M
# [04/16 15:55:34 d2.utils.events]:  eta: 0:01:58  iter: 759  total_loss: 0.2387  loss_cls: 0.04696  loss_box_reg: 0.06262  loss_mask: 0.0973  loss_rpn_cls: 0.0001401  loss_rpn_loc: 0.009609     lr: 0.00018981  max_mem: 2858M
# [04/16 15:55:44 d2.utils.events]:  eta: 0:01:47  iter: 779  total_loss: 0.219  loss_cls: 0.05019  loss_box_reg: 0.05484  loss_mask: 0.1113  loss_rpn_cls: 8.673e-05  loss_rpn_loc: 0.005618     lr: 0.00019481  max_mem: 2858M
# [04/16 15:55:53 d2.utils.events]:  eta: 0:01:33  iter: 799  total_loss: 0.1867  loss_cls: 0.05579  loss_box_reg: 0.04647  loss_mask: 0.08381  loss_rpn_cls: 0.0001249  loss_rpn_loc: 0.005944     lr: 0.0001998  max_mem: 2858M
# Loss has not improved for 100 iterations
# [04/16 15:56:03 d2.utils.events]:  eta: 0:01:26  iter: 819  total_loss: 0.2369  loss_cls: 0.06117  loss_box_reg: 0.054  loss_mask: 0.08715  loss_rpn_cls: 0.0001702  loss_rpn_loc: 0.005658     lr: 0.0002048  max_mem: 2858M
# [04/16 15:56:12 d2.utils.events]:  eta: 0:01:16  iter: 839  total_loss: 0.1938  loss_cls: 0.0503  loss_box_reg: 0.05383  loss_mask: 0.07875  loss_rpn_cls: 0.0003744  loss_rpn_loc: 0.008041     lr: 0.00020979  max_mem: 2858M
# [04/16 15:56:22 d2.utils.events]:  eta: 0:01:06  iter: 859  total_loss: 0.1886  loss_cls: 0.04761  loss_box_reg: 0.04597  loss_mask: 0.08758  loss_rpn_cls: 0.0008067  loss_rpn_loc: 0.004981     lr: 0.00021479  max_mem: 2858M
# [04/16 15:56:32 d2.utils.events]:  eta: 0:00:56  iter: 879  total_loss: 0.1667  loss_cls: 0.03372  loss_box_reg: 0.04183  loss_mask: 0.0799  loss_rpn_cls: 0.000279  loss_rpn_loc: 0.004957     lr: 0.00021978  max_mem: 2858M
# [04/16 15:56:41 d2.utils.events]:  eta: 0:00:49  iter: 899  total_loss: 0.2147  loss_cls: 0.05082  loss_box_reg: 0.04263  loss_mask: 0.0915  loss_rpn_cls: 0.0001081  loss_rpn_loc: 0.01272     lr: 0.00022478  max_mem: 2858M
# [04/16 15:56:51 d2.utils.events]:  eta: 0:00:37  iter: 919  total_loss: 0.1592  loss_cls: 0.04344  loss_box_reg: 0.04324  loss_mask: 0.07021  loss_rpn_cls: 3.525e-05  loss_rpn_loc: 0.004479     lr: 0.00022977  max_mem: 2858M
# [04/16 15:57:00 d2.utils.events]:  eta: 0:00:28  iter: 939  total_loss: 0.1883  loss_cls: 0.04778  loss_box_reg: 0.04003  loss_mask: 0.09247  loss_rpn_cls: 0.0001427  loss_rpn_loc: 0.006523     lr: 0.00023477  max_mem: 2858M
# Loss has not improved for 100 iterations
# [04/16 15:57:10 d2.utils.events]:  eta: 0:00:18  iter: 959  total_loss: 0.1847  loss_cls: 0.03545  loss_box_reg: 0.04954  loss_mask: 0.08907  loss_rpn_cls: 0.0002521  loss_rpn_loc: 0.005098     lr: 0.00023976  max_mem: 2858M
# [04/16 15:57:19 d2.utils.events]:  eta: 0:00:09  iter: 979  total_loss: 0.191  loss_cls: 0.04756  loss_box_reg: 0.04355  loss_mask: 0.08286  loss_rpn_cls: 7.344e-05  loss_rpn_loc: 0.003825     lr: 0.00024476  max_mem: 2858M
# [04/16 15:57:29 d2.utils.events]:  eta: 0:00:00  iter: 999  total_loss: 0.197  loss_cls: 0.05843  loss_box_reg: 0.04906  loss_mask: 0.08436  loss_rpn_cls: 0.0003237  loss_rpn_loc: 0.005512     lr: 0.00024975  max_mem: 2858M
# os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
# [04/16 15:57:30 d2.data.datasets.coco]: Loaded 40 images in COCO format from /content/drive/MyDrive/CocaCola Images/test/labels_my-project-name_2024-04-16-02-40-51.json
# [04/16 15:57:30 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [04/16 15:57:30 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [04/16 15:57:30 d2.data.common]: Serializing 40 elements to byte tensors and concatenating them all ...
# [04/16 15:57:30 d2.data.common]: Serialized dataset takes 0.03 MiB
# [04/16 15:57:30 d2.evaluation.evaluator]: Start inference on 40 batches
# os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
# [04/16 15:57:32 d2.evaluation.evaluator]: Inference done 11/40. Dataloading: 0.0017 s/iter. Inference: 0.1092 s/iter. Eval: 0.0013 s/iter. Total: 0.1122 s/iter. ETA=0:00:03
# os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
# [04/16 15:57:35 d2.evaluation.evaluator]: Total inference time: 0:00:04.403358 (0.125810 s / iter per device, on 1 devices)
# [04/16 15:57:35 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:03 (0.113323 s / iter per device, on 1 devices)
# [04/16 15:57:35 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [04/16 15:57:35 d2.evaluation.coco_evaluation]: Saving results to ./output/inference/ca_test/coco_instances_results.json
# [04/16 15:57:35 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [04/16 15:57:35 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [04/16 15:57:35 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.01 seconds.
# [04/16 15:57:35 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [04/16 15:57:35 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.591
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.772
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.721
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.419
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.655
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.379
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.766
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.777
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.750
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.797
# [04/16 15:57:35 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 59.088 | 77.210 | 72.148 |  nan  | 41.853 | 65.480 |
# [04/16 15:57:35 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [04/16 15:57:35 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|
# | coca       | 58.429 | not_coca   | 59.747 |
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# [04/16 15:57:35 d2.evaluation.fast_eval_api]: Evaluate annotation type *segm*
# [04/16 15:57:35 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.02 seconds.
# [04/16 15:57:35 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [04/16 15:57:35 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.631
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.795
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.740
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.426
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.703
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.405
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.788
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.793
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.797
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.810
# [04/16 15:57:36 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 63.115 | 79.468 | 73.997 |  nan  | 42.557 | 70.347 |
# [04/16 15:57:36 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [04/16 15:57:36 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|
# | coca       | 62.867 | not_coca   | 63.363 |
# [04/16 15:57:36 detectron2]: Evaluation results for ca_test in csv format:
# [04/16 15:57:36 d2.evaluation.testing]: copypaste: Task: bbox
# [04/16 15:57:36 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [04/16 15:57:36 d2.evaluation.testing]: copypaste: 59.0877,77.2100,72.1483,nan,41.8531,65.4804
# [04/16 15:57:36 d2.evaluation.testing]: copypaste: Task: segm
# [04/16 15:57:36 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [04/16 15:57:36 d2.evaluation.testing]: copypaste: 63.1148,79.4675,73.9969,nan,42.5570,70.3469
# OrderedDict([('bbox',
#               {'AP': 59.087695890139315,
#                'AP50': 77.2099896463008,
#                'AP75': 72.1482883978122,
#                'APs': nan,
#                'APm': 41.85305436652262,
#                'APl': 65.48043145865621,
#                'AP-coca': 58.42855016657121,
#                'AP-not_coca': 59.746841613707424}),
#              ('segm',
#               {'AP': 63.11481041753291,
#                'AP50': 79.46753312380021,
#                'AP75': 73.99689508288363,
#                'APs': nan,
#                'APm': 42.55695316306595,
#                'APl': 70.34694052521337,
#                'AP-coca': 62.866510343566226,
#                'AP-not_coca': 63.363110491499576})])

# %%
register_coco_instances("val_2", {}, f"/content/drive/MyDrive/test_val/labels_test_val_2024-04-16-04-57-51.json", f"/content/drive/MyDrive/test_val/")

# %%
register_coco_instances("val_4", {}, f"/content/drive/MyDrive/not_coca_1/labels_notcoca_1_2024-04-16-05-14-40.json", f"/content/drive/MyDrive/not_coca_1/")

# %% [markdown]
# # Test model and show example output

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")  # path to the model we just trained
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.2   # set a custom testing threshold
predictor = DefaultPredictor(cfg)

dataset_dicts = DatasetCatalog.get("val_2")
for d in random.sample(dataset_dicts, 1):
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)
    v = Visualizer(im[:, :, ::-1],
                   metadata=MetadataCatalog.get(cfg.DATASETS.TRAIN[0]),
                   scale=0.5,
                   instance_mode=ColorMode.IMAGE_BW
    )
    out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    im = Image.fromarray(out.get_image()[:, :, ::-1])
    im
# Out:
# [04/16 15:26:00 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output/model_final.pth ...
# [04/16 15:26:00 d2.data.datasets.coco]: Loaded 3 images in COCO format from /content/drive/MyDrive/test_val/labels_test_val_2024-04-16-04-57-51.json

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")  # path to the model we just trained
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.2   # set a custom testing threshold
predictor = DefaultPredictor(cfg)

dataset_dicts = DatasetCatalog.get("val_4")
for d in random.sample(dataset_dicts, 1):
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)
    v = Visualizer(im[:, :, ::-1],
                   metadata=MetadataCatalog.get(cfg.DATASETS.TRAIN[0]),
                   scale=0.5,
                   instance_mode=ColorMode.IMAGE_BW
    )
    out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    im = Image.fromarray(out.get_image()[:, :, ::-1])
    im
# Out:
# [04/16 16:34:15 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output/model_final.pth ...
# [04/16 16:34:15 d2.data.datasets.coco]: Loaded 4 images in COCO format from /content/drive/MyDrive/not_coca_1/labels_notcoca_1_2024-04-16-05-14-40.json

# %%
im
# Out:
# <PIL.Image.Image image mode=RGB size=625x2000>

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")  # path to the model we just trained
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.2   # set a custom testing threshold
predictor = DefaultPredictor(cfg)

dataset_dicts = DatasetCatalog.get("rami")
for d in dataset_dicts:
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)
    v = Visualizer(im[:, :, ::-1],
                   metadata=MetadataCatalog.get(cfg.DATASETS.TRAIN[0]),
                   scale=0.5,
                   instance_mode=ColorMode.IMAGE_BW
    )
    out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    im = Image.fromarray(out.get_image()[:, :, ::-1])
    im
# Out:
# [04/16 16:37:29 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output/model_final.pth ...
# [04/16 16:37:29 d2.data.datasets.coco]: Loaded 1 images in COCO format from /content/drive/MyDrive/rami/labels_rami_2024-04-16-05-28-00.json

# %%
register_coco_instances("val_5", {}, f"/content/drive/MyDrive/testing/labels_my-project-name_2024-04-16-03-40-55.json", f"/content/drive/MyDrive/testing/")

# %%
register_coco_instances("rami", {}, f"/content/drive/MyDrive/rami/labels_rami_2024-04-16-05-28-00.json", f"/content/drive/MyDrive/rami/")

# %% [markdown]
# # Download trained model for future inference

# %%
from google.colab import files
files.download(os.path.join(cfg.OUTPUT_DIR, "model_final.pth"))
